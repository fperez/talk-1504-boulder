# %% [markdown]
# # The IPython kernel is a polyglot

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Julia: seamless 2-way integration

# %%
# %load_ext julia.magic
# %julia @pyimport matplotlib.pyplot as plt
# %julia @pyimport numpy as np
# Out:
# Initializing Julia interpreter. This may take some time...

# %%
# %%julia
# # Note how we mix numpy and julia:
# t = linspace(0,2*pi,1000); # use the julia linspace
# s = sin(3*t + 4*np.cos(2*t)); # use the numpy cosine and julia sine
# fig = plt.gcf()
# plt.plot(t, s, color="red", linewidth=2.0, linestyle="--")

# %%
fig = %julia fig
fig.suptitle("Adding a title!")
fig

# %% [markdown]
# # R

# %%
X = np.array([0,1,2,3,4])
Y = np.array([3,5,4,6,7])
# Now, load R support
# %load_ext rpy2.ipython

# %%
# %%R -i X,Y -o XYcoef
# XYlm = lm(Y~X)
# XYcoef = coef(XYlm)
# print(summary(XYlm))
# par(mfrow=c(2,2))
# plot(XYlm)
# Out:
# Call:
# lm(formula = Y ~ X)
#
# Residuals:
#    1    2    3    4    5
# -0.2  0.9 -1.0  0.1  0.2
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   3.2000     0.6164   5.191   0.0139 *
# X             0.9000     0.2517   3.576   0.0374 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7958 on 3 degrees of freedom
# Multiple R-squared:   0.81,	Adjusted R-squared:  0.7467
# F-statistic: 12.79 on 1 and 3 DF,  p-value: 0.03739

# %% [markdown]
# And now, `XYcoef` is a *Python* variable:

# %%
XYcoef
# Out:
# <FloatVector - Python:0x11a1d2908 / R:0x1148a7990>
# [3.200000, 0.900000]

# %% [markdown]
# # Cython: Speed up Python, C integration

# %%
# %load_ext Cython

# %%
def f(x):
    return x**2-x

def integrate_f(a, b, N):
    s = 0; dx = (b-a)/N
    for i in range(N):
        s += f(a+i*dx)
    return s * dx

# %%
# %%cython
# cdef double fcy(double x) except? -2:
#     return x**2-x
#
# def integrate_fcy(double a, double b, int N):
#     cdef int i
#     cdef double s, dx
#     s = 0; dx = (b-a)/N
#     for i in range(N):
#         s += fcy(a+i*dx)
#     return s * dx

# %%
# %timeit integrate_f(0, 1, 100)
# %timeit integrate_fcy(0, 1, 100)
# Out:
# 10000 loops, best of 3: 33.3 µs per loop
# The slowest run took 6.02 times longer than the fastest. This could mean that an intermediate result is being cached
# 1000000 loops, best of 3: 317 ns per loop

# %% [markdown]
# # Or Fortran

# %%
# %load_ext fortranmagic

# %%
# %%fortran
# subroutine f1(x, y, n)
#     real, intent(in), dimension(n) :: x
#     real, intent(out), dimension(n) :: y
#     !intent(hide) :: n
#     y = sin(x**3)-cos(x)
# end subroutine f1
# Out:
# 	Building module "_fortran_magic_23d285fc63b4f50dbc80c492146df96c"...
# 		Constructing wrapper function "f1"...
# 		  y = f1(x,[n])
# 	Wrote C/API module "_fortran_magic_23d285fc63b4f50dbc80c492146df96c" to file "/var/folders/j1/n8kn9ftd7257n2rvkkzlj3mc0010dw/T/tmpfmy1990f/src.macosx-10.5-x86_64-3.4/_fortran_magic_23d285fc63b4f50dbc80c492146df96cmodule.c"

# %%
t = np.linspace(0,2* np.pi, 1000)
plt.plot(t, f1(t));

# %% [markdown]
# # Bash

# %%
# %%bash
# uname -a
# echo $PWD
# Out:
# Darwin denali.local 14.3.0 Darwin Kernel Version 14.3.0: Mon Mar 23 11:59:05 PDT 2015; root:xnu-2782.20.48~5/RELEASE_X86_64 x86_64
# /Users/fperez/talks/slides/1504-boulder
