# %% [markdown]
# # This is the IPython Notebook
#
# * A Web-based interactive computing system.
# * Code, results and narrative in one place.
# * Full power of modern web browsers.

# %% [markdown]
# # Fluid everyday scientific computing <!--====-->

# %%
# %pylab inline
# %run talktools
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>
# /*
#    Simple CSS styling for using IPython Notebooks for talks.
#
#    Author: Fernando Perez <fernando.perez@berkeley.edu>
# */
#
# #notebook
# {
#     padding-top: 0;
# }
#
# #notebook-container
# {
#     padding-top: 0;
# }
#
#
# .end_space
# {
#     min-height: 0;
# }
#
# .talk-title
# {
#   color: #498AF3;
#   font-size: 220%;
#   font-weight:bold;
#   line-height: 1.2;
#   margin: 10px 50px 10px;
#   }
#
# .talk-subtitle
# {
#   color: #386BBC;
#   font-size: 150%;
#   font-weight:bold;
#   line-height: 1.2;
#   margin: 20px 50px 20px;
#   }
#
# .slide-header, p.slide-header
# {
#   color: #498AF3;
#   font-size: 180%;
#   font-weight:bold;
#   margin: 0px 20px 10px;
#   page-break-before: always;
#   text-align: center;
#   }
#
# .rendered_html
# {
#   color: #2C5494;
#   font-family: Ubuntu;
#   font-size: 140%;
#   line-height: 1.1;
#   margin: 0.5em 0;
#   }
#
# .rendered_html h1
# {
# ...

# %%
def plot_bessel(xmax=20, nmin=0, nmax=10, nstep=3):
    from scipy import special
    x = np.linspace(0, xmax, 200)
    f, ax = plt.subplots()
    for n in range(nmin, nmax+1, nstep):
        plt.plot(x, special.jn(n, x), label=r'$J_{%i(x)}$' % n)
    plt.grid()
    plt.legend()
    plt.title('Bessel Functions')

plot_bessel()

# %%
from IPython.html.widgets import interact

interact(plot_bessel, xmax=(10,100.), nmin=(0, 10),
        nmax=(10, 30), nstep=(1,5));

# %% [markdown]
# ## Document your workflows
#
# You can *italicize*, **boldface**
#
# * build
# * lists
#
# and embed code meant for illustration instead of execution in Python:
#
#     def f(x):
#         """a docstring"""
#         return x**2
#
# or other languages:
#
#     if (i=0; i<n; i++) {
#       printf("hello %d\n", i);
#       x += 4;
#     }

# %% [markdown]
# Courtesy of MathJax, you can include mathematical expressions both inline:
# $e^{i\pi} + 1 = 0$  and displayed:
#
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %% [markdown]
# <!--====-->
# ## Load remote code
#
# Use ``%load`` with any local or remote url, such as [the always useful Matplotlib Gallery!](http://matplotlib.org/gallery.html)

# %%
# %load http://matplotlib.org/mpl_examples/showcase/xkcd.py

# %% [markdown]
# <!--====-->
# ## Rich displays: include anything a browser can show
#
# ### Images

# %%
from IPython.display import Image
Image('logo.png')

# %%
from IPython.display import HTML
HTML("""<table> <tr>
<th>Header 1</th>
<th>Header 2</th></tr>
<tr><td>row 1, cell 1</td>
<td>row 1, cell 2</td></tr>
<tr><td>row 2, cell 1</td>
<td>row 2, cell 2</td></tr></table>""")
# Out:
# <table> <tr>
# <th>Header 1</th>
# <th>Header 2</th></tr>
# <tr><td>row 1, cell 1</td>
# <td>row 1, cell 2</td></tr>
# <tr><td>row 2, cell 1</td>
# <td>row 2, cell 2</td></tr></table>

# %% [markdown]
# ## Loading routine datasets

# %%
from IPython.display import display
import pandas.io.data as web
from datetime import datetime

stock = web.DataReader( 'MSFT', 'yahoo', start=datetime(2012, 1, 1))
display(stock[:3])
stock['Close'].plot(title='Closing Price');
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2012-01-03  26.55  26.96  26.39  26.77  64731500      24.42
# 2012-01-04  26.82  27.47  26.78  27.40  80516100      25.00
# 2012-01-05  27.38  27.73  27.29  27.68  56081400      25.25

# %% [markdown]
# ### Audio

# %%
plot_audio('voice.wav')
Audio('voice.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <!--====-->
# ### Video
#
# **Note:** credit for this animation goes to [Chris Kees, from the Army ERDC](http://chl.erdc.usace.army.mil/chl.aspx?p=s&a=Persons;401), it represents a shallow water flow simulation created with his Proteus code.

# %%
import base64
from IPython.display import HTML
video = open("animation.m4v", "rb").read()
video_encoded = base64.b64encode(video).decode('ascii')
data = '<video controls alt="test" src="data:video/x-m4v;base64,{0}">'.format(video_encoded)
HTML(data=data)
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">

# %% [markdown]
# And more exotic objects can also be displayed, as long as their representation supports
# the IPython display protocol.
#
# For example, videos hosted externally on YouTube are easy to load (and writing a similar wrapper for other
# hosted content is trivial):

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('sjfsUzECqK0', start=48)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/sjfsUzECqK0?start=48"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Embed entire websites
# <!--====-->

# %%
from IPython.display import IFrame
IFrame('http://en.mobile.wikipedia.org/?useformat=mobile', width=650, height=350)
# Out:
#         <iframe
#             width="650"
#             height="350"
#             src="http://en.mobile.wikipedia.org/?useformat=mobile"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <!--====-->
# ## Mathematical output with LaTeX representations
#
# Objects can have a LaTeX representation, rendered thanks to MathJax:

# %%
from IPython.display import Math
Math(r'F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx')
# Out:
# $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$

# %%
from IPython.display import Latex
Latex(r"""\begin{eqnarray}
\nabla \times \vec{\mathbf{B}} -\, \frac1c\, 
\frac{\partial\vec{\mathbf{E}}}{\partial t} & = & \frac{4\pi}{c}\vec{\mathbf{j}} \\
\nabla \cdot \vec{\mathbf{E}} & = & 4 \pi \rho \\
\nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, 
\frac{\partial\vec{\mathbf{B}}}{\partial t} & = & \vec{\mathbf{0}} \\
\nabla \cdot \vec{\mathbf{B}} & = & 0 
\end{eqnarray}""")
# Out:
# \begin{eqnarray}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\,
# \frac{\partial\vec{\mathbf{E}}}{\partial t} & = & \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = & 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\,
# \frac{\partial\vec{\mathbf{B}}}{\partial t} & = & \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = & 0
# \end{eqnarray}

# %% [markdown]
# <!--====-->
# ## This plays very nicely with SymPy

# %%
from sympy.interactive.printing import init_printing
init_printing(use_latex=True)
from sympy import *
x, y = symbols("x y")

# %%
eq = ((x+y)**10 * (x+1)); eq
# Out:
#                10
# (x + 1)⋅(x + y)

# %%
expand(eq)
# Out:
#  11       10      10       9  2       9          8  3       8  2        7  4
# x   + 10⋅x  ⋅y + x   + 45⋅x ⋅y  + 10⋅x ⋅y + 120⋅x ⋅y  + 45⋅x ⋅y  + 210⋅x ⋅y  +
#
#       7  3        6  5        6  4        5  6        5  5        4  7
#  120⋅x ⋅y  + 252⋅x ⋅y  + 210⋅x ⋅y  + 210⋅x ⋅y  + 252⋅x ⋅y  + 120⋅x ⋅y  + 210⋅x
#
# 4  6       3  8        3  7       2  9       2  8      10         9    10
#  ⋅y  + 45⋅x ⋅y  + 120⋅x ⋅y  + 10⋅x ⋅y  + 45⋅x ⋅y  + x⋅y   + 10⋅x⋅y  + y

# %%
(1/cos(x)).series(x, 0, 6)
# Out:
#      2      4
#     x    5⋅x     ⎛ 6⎞
# 1 + ── + ──── + O⎝x ⎠
#     2     24

# %%
diff(cos(x**2)**2 / (1+x), x)
# Out:
#          ⎛ 2⎞    ⎛ 2⎞      2⎛ 2⎞
#   4⋅x⋅sin⎝x ⎠⋅cos⎝x ⎠   cos ⎝x ⎠
# - ─────────────────── - ────────
#          x + 1                 2
#                         (x + 1)
